# %%
import waves as w

# %%
w.bar()

# %%
import matplotlib.animation as animation
from IPython.display import HTML

ani = animation.FuncAnimation(fig, w.update, interval=100, repeat=True, repeat_delay=10000, frames=nt)
ani.save("bar.gif")
    
HTML(ani.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import matplotlib.animation as animation
#       2 from IPython.display import HTML
# ----> 4 ani = animation.FuncAnimation(fig, w.update, interval=100, repeat=True, repeat_delay=10000, frames=nt)
#       5 ani.save("bar.gif")
#       7 HTML(ani.to_jshtml())
#
# NameError: name 'fig' is not defined
